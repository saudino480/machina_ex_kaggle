# %%
### packages
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('test.csv')

# %%
train_subset = pd.concat([train_data[['Id']],train_data.iloc[:,40:60]],axis=1)

# %%
train_subset.isna().sum()
# Out:
# Id               0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     2
# BsmtHalfBath     2
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      1
# TotRmsAbvGrd     0
# Functional       2
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt     78
# dtype: int64

# %%
def na_as_none(df, col_list):
    for column in col_list:
        df[column][df[column].isna()] = 'None'

# %%
none_cols = ['FireplaceQu','GarageType']

# %%
na_as_none(train_subset,none_cols)
# Out:
# /Users/mdrozdov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# train_subset.FireplaceQu = pd.get_dummies(train_subset.FireplaceQu).drop('None',axis=1)

train_subset[['FireplaceQu']]
# Out:
#      FireplaceQu
# 0           None
# 1           None
# 2             TA
# 3             Gd
# 4           None
# 5             TA
# 6           None
# 7             Gd
# 8             Po
# 9           None
# 10            Fa
# 11          None
# 12          None
# 13            TA
# 14          None
# 15            Gd
# 16          None
# 17            Gd
# 18            Gd
# 19            Gd
# 20            Ex
# 21            Gd
# 22          None
# 23          None
# 24            Gd
# 25            Gd
# 26            TA
# 27            Gd
# 28          None
# 29            Gd
# ...          ...
# 1429        None
# 1430        None
# 1431        None
# 1432        None
# 1433        None
# 1434          Gd
# 1435          Gd
# 1436          TA
# 1437        None
# 1438        None
# 1439        None
# 1440          Gd
# 1441        None
# 1442          Gd
# 1443          Gd
# 1444        None
# 1445        None
# 1446          TA
# 1447        None
# 1448        None
# 1449        None
# 1450        None
# 1451          TA
# 1452        None
# 1453        None
# 1454        None
# 1455        None
# 1456          TA
# 1457        None
# 1458          TA
#
# [1459 rows x 1 columns]
