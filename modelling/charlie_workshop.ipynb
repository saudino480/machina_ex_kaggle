# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LassoCV, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn import datasets
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, mean_squared_error
from modelling_functions import *

# %%
# !dir "../mikedollar/clean_data/train_fe.csv"
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is F8BF-4A24
#
#  Directory of C:\Users\Charlie\Google Drive\data science\projects\machina_ex_kaggle\mikedollar\clean_data
#
# 07/25/2019  10:44 AM    <DIR>          .
# 07/25/2019  10:44 AM    <DIR>          ..
# 07/24/2019  10:40 PM           137,505 charlie_slice_clean.csv
# 07/24/2019  10:40 PM           125,379 mikejr_slice_clean.csv
# 07/24/2019  10:40 PM           183,318 mike_slice_clean.csv
# 07/24/2019  10:40 PM           176,213 sam_slice_clean.csv
# 07/25/2019  10:44 AM           561,520 test_fe.csv
# 07/24/2019  10:40 PM           615,396 train_clean.csv
# 07/25/2019  10:44 AM           571,655 train_fe.csv
#                7 File(s)      2,370,986 bytes
#                2 Dir(s)  144,955,506,688 bytes free

# %%
test = pd.read_csv("../mikedollar/clean_data/test_fe.csv").set_index('Id')
train = pd.read_csv("../mikedollar/clean_data/train_fe.csv").set_index('Id')

# %%
train.head()
# Out:
#     MSSubClass MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# Id
# 1           60       RL   Pave  None      Reg         Lvl    AllPub   NotCulD
# 2           20       RL   Pave  None      Reg         Lvl    AllPub   NotCulD
# 3           60       RL   Pave  None      IRG         Lvl    AllPub   NotCulD
# 4           70       RL   Pave  None      IRG         Lvl    AllPub   NotCulD
# 5           60       RL   Pave  None      IRG         Lvl    AllPub   NotCulD
#
#    LandSlope Neighborhood  ... TotalBath   FPperSF  YearRemodAdd_tog  \
# Id                         ...
# 1        Gtl     Med_High  ...         3  0.000000                 1
# 2        Gtl         High  ...         2  0.000396                 1
# 3        Gtl     Med_High  ...         3  0.000370                 1
# 4        Gtl     Med_High  ...         1  0.000404                 1
# 5        Gtl          Lux  ...         3  0.000299                 1
#
# ...
